# %%
# to know where you are on your computer
import os
os.getcwd()
# Out:
# 'C:\\Users\\ivana\\Dropbox\\Education\\X\\Python for Data Science\\Lab1'

# %%
import pandas as pd

# %%
data = pd.read_csv("gapminder_gdp_oceania.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
data = pd.read_csv(
    "gapminder_gdp_oceania.csv", 
    index_col="country")

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
print(data.columns)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
data.T
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
americas = pd.read_csv("gapminder_gdp_americas.csv", 
                      index_col="country")

# %%
americas.shape
# Out:
# (25, 13)

# %%
americas.head()
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
# Canada     Americas    11367.161120    12489.950060    13462.485550
# Chile      Americas     3939.978789     4315.622723     4519.094331
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
# Canada       16076.588030    18970.570860    22090.883060    22898.792140
# Chile         5106.654313     5494.024437     4756.763836     5095.665738
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# ...

# %%
americas.tail()
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Puerto Rico          Americas     3081.959785     3907.156189     5108.344630
# Trinidad and Tobago  Americas     3023.271928     4100.393400     4997.523971
# United States        Americas    13990.482080    14847.127120    16173.145860
# Uruguay              Americas     5716.766744     6150.772969     5603.357717
# Venezuela            Americas     7689.799761     9802.466526     8422.974165
#
#                      gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Puerto Rico             6929.277714     9123.041742     9770.524921
# Trinidad and Tobago     5621.368472     6619.551419     7899.554209
# United States          19530.365570    21806.035940    24072.632130
# Uruguay                 5444.619620     5703.408898     6504.339663
# Venezuela               9541.474188    10505.259660    13143.950950
#
# ...

# %%
americas.head?

# %%
europe = pd.read_csv(
    "gapminder_gdp_europe.csv", 
     index_col="country")

# %%
europe.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
# how to access data from "europe"?
# 1) with iloc : with the index (not convenient)
europe.iloc[0, 1]
# Out:
# 1942.2842440000002

# %%
europe.iloc[3, 2]
# Out:
# 1709.683679

# %%
europe.loc["France", "gdpPercap_1967"]
# Out:
# 12999.91766

# %%
europe.loc["France", :]  # : means all values
# Out:
# gdpPercap_1952     7029.809327
# gdpPercap_1957     8662.834898
# gdpPercap_1962    10560.485530
# gdpPercap_1967    12999.917660
# gdpPercap_1972    16107.191710
# gdpPercap_1977    18292.635140
# gdpPercap_1982    20293.897460
# gdpPercap_1987    22066.442140
# gdpPercap_1992    24703.796150
# gdpPercap_1997    25889.784870
# gdpPercap_2002    28926.032340
# gdpPercap_2007    30470.016700
# Name: France, dtype: float64

# %%
europe.loc[:, "gdpPercap_1997"]  # : means all values
# Out:
# country
# Albania                    3193.054604
# Austria                   29095.920660
# Belgium                   27561.196630
# Bosnia and Herzegovina     4766.355904
# Bulgaria                   5970.388760
# Croatia                    9875.604515
# Czech Republic            16048.514240
# Denmark                   29804.345670
# Finland                   23723.950200
# France                    25889.784870
# Germany                   27788.884160
# Greece                    18747.698140
# Hungary                   11712.776800
# Iceland                   28061.099660
# Ireland                   24521.947130
# Italy                     24675.024460
# Montenegro                 6465.613349
# Netherlands               30246.130630
# Norway                    41283.164330
# Poland                    10159.583680
# Portugal                  17641.031560
# Romania                    7346.547557
# Serbia                     7914.320304
# Slovak Republic           12126.230650
# ...

# %%
atom_name = "helium"
print(atom_name[1:3])
# Out:
# el

# %%
europe["Slovenia":"Switzerland"]  # what's the difference?
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Slovenia        4215.041741     5862.276629     7402.303395     9405.489397
# Spain           3834.034742     4564.802410     5693.843879     7993.512294
# Sweden          8527.844662     9911.878226    12329.441920    15258.296970
# Switzerland    14734.232750    17909.489730    20431.092700    22966.144320
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Slovenia        12383.48620     15277.03017     17866.72175     18678.53492
# Spain           10638.75131     13236.92117     13926.16997     15764.98313
# Sweden          17832.02464     18855.72521     20667.38125     23586.92927
# Switzerland     27195.11304     26982.29052     28397.71512     30281.70459
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Slovenia        14214.71681     17161.10735     20660.01936     25768.25759
# ...

# %%
europe.loc["Slovenia":"Switzerland"]
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Slovenia        4215.041741     5862.276629     7402.303395     9405.489397
# Spain           3834.034742     4564.802410     5693.843879     7993.512294
# Sweden          8527.844662     9911.878226    12329.441920    15258.296970
# Switzerland    14734.232750    17909.489730    20431.092700    22966.144320
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Slovenia        12383.48620     15277.03017     17866.72175     18678.53492
# Spain           10638.75131     13236.92117     13926.16997     15764.98313
# Sweden          17832.02464     18855.72521     20667.38125     23586.92927
# Switzerland     27195.11304     26982.29052     28397.71512     30281.70459
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Slovenia        14214.71681     17161.10735     20660.01936     25768.25759
# ...

# %%
europe.loc[["Slovenia", "Switzerland"]] # is also possible but with double brackets. 
# Otherwise a comma means you're switching from rows to columns.
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Slovenia        4215.041741     5862.276629     7402.303395     9405.489397
# Switzerland    14734.232750    17909.489730    20431.092700    22966.144320
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Slovenia        12383.48620     15277.03017     17866.72175     18678.53492
# Switzerland     27195.11304     26982.29052     28397.71512     30281.70459
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Slovenia        14214.71681     17161.10735     20660.01936     25768.25759
# Switzerland     31871.53030     32135.32301     34480.95771     37506.41907

# %%
type(europe["Slovenia":"Switzerland"])
# Out:
# pandas.core.frame.DataFrame

# %%
print(europe.loc["Italy", "gdpPercap_1957":"gdpPercap_1967"])
# Out:
# gdpPercap_1957     6248.656232
# gdpPercap_1962     8243.582340
# gdpPercap_1967    10022.401310
# Name: Italy, dtype: float64

# %%
type(europe.loc["Italy", "gdpPercap_1957":"gdpPercap_1967"])
# Out:
# pandas.core.series.Series

# %%
europe.loc["Italy", "gdpPercap_1957":"gdpPercap_1967"].max()
# Out:
# 10022.40131

# %%
subset = europe.loc["Italy" : "Poland",
                    "gdpPercap_1957":"gdpPercap_1977"]

# %%
subset
# Out:
#              gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  \
# country
# Italy           6248.656232     8243.582340    10022.401310    12269.273780
# Montenegro      3682.259903     4649.593785     5907.850937     7778.414017
# Netherlands    11276.193440    12790.849560    15363.251360    18794.745670
# Norway         11653.973040    13450.401510    16361.876470    18965.055510
# Poland          4734.253019     5338.752143     6557.152776     8006.506993
#
#              gdpPercap_1977
# country
# Italy          14255.984750
# Montenegro      9595.929905
# Netherlands    21209.059200
# Norway         23311.349390
# Poland          9508.141454

# %%
# where are the values greater than 10000?
# hint:
age = 42
print(age > 30)
print(age >= 50)
# Out:
# True
# False

# %%
subset > 10_000  # 10_000 is a syntactic sugar
# Out:
#              gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  \
# country
# Italy                 False           False            True            True
# Montenegro            False           False           False           False
# Netherlands            True            True            True            True
# Norway                 True            True            True            True
# Poland                False           False           False           False
#
#              gdpPercap_1977
# country
# Italy                  True
# Montenegro            False
# Netherlands            True
# Norway                 True
# Poland                False

# %%
10_000 == 10000
# Out:
# True

# %%
subset.shape
# Out:
# (5, 5)

# %%
subset[subset > 10_000]
# Out:
#              gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  \
# country
# Italy                   NaN             NaN     10022.40131     12269.27378
# Montenegro              NaN             NaN             NaN             NaN
# Netherlands     11276.19344     12790.84956     15363.25136     18794.74567
# Norway          11653.97304     13450.40151     16361.87647     18965.05551
# Poland                  NaN             NaN             NaN             NaN
#
#              gdpPercap_1977
# country
# Italy           14255.98475
# Montenegro              NaN
# Netherlands     21209.05920
# Norway          23311.34939
# Poland                  NaN

# %%
subset[subset > 10_000].mean()
# Out:
# gdpPercap_1957    11465.083240
# gdpPercap_1962    13120.625535
# gdpPercap_1967    13915.843047
# gdpPercap_1972    16676.358320
# gdpPercap_1977    19592.131113
# dtype: float64

# %%
data.mean()  # beware, column-wise
# Out:
# gdpPercap_1952    10298.085650
# gdpPercap_1957    11598.522455
# gdpPercap_1962    12696.452430
# gdpPercap_1967    14495.021790
# gdpPercap_1972    16417.333380
# gdpPercap_1977    17283.957605
# gdpPercap_1982    18554.709840
# gdpPercap_1987    20448.040160
# gdpPercap_1992    20894.045885
# gdpPercap_1997    24024.175170
# gdpPercap_2002    26938.778040
# gdpPercap_2007    29810.188275
# dtype: float64

# %%
mask_higher = europe > europe.mean()

# %%
mask_higher
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
# Croatia                          False           False           False
# Czech Republic                    True            True            True
# Denmark                           True            True            True
# Finland                           True            True            True
# France                            True            True            True
# Germany                           True            True            True
# Greece                           False           False           False
# ...

# %%
mask_higher.aggregate("mean", axis=1) # along the columns
# Out:
# country
# Albania                   0.000000
# Austria                   1.000000
# Belgium                   1.000000
# Bosnia and Herzegovina    0.000000
# Bulgaria                  0.000000
# Croatia                   0.000000
# Czech Republic            0.500000
# Denmark                   1.000000
# Finland                   1.000000
# France                    1.000000
# Germany                   1.000000
# Greece                    0.333333
# Hungary                   0.000000
# Iceland                   1.000000
# Ireland                   0.333333
# Italy                     0.500000
# Montenegro                0.000000
# Netherlands               1.000000
# Norway                    1.000000
# Poland                    0.000000
# Portugal                  0.000000
# Romania                   0.000000
# Serbia                    0.000000
# Slovak Republic           0.000000
# Slovenia                  0.333333
# Spain                     0.333333
# ...

# %%
# exercise:
# find the gdp of Serbia in 2007

# %%
europe.aggregate
# Out:
# <bound method DataFrame.aggregate of                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
europe.loc["Serbia", "gdpPercap_2007"]
# Out:
# 9786.534714

# %%
europe.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
# todo: extract a list with the years only in the column names, as integers

# %%
some_names = ["Sylvain", "Mathurin", "Alice", "Bob"]

long_names = []
for name in some_names:
    print(name)
    if len(name) >= 6:
        print("this is a long name")
        long_names.append(name)
# Out:
# Sylvain
# this is a long name
# Mathurin
# this is a long name
# Alice
# Bob

# %%
long_names
# Out:
# ['Sylvain', 'Mathurin']

# %%
years = []
for col in europe.columns:
    year = int(col[-4:])
    years.append(year)

# %%
years
# Out:
# [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007]

# %%
# you can also use .strip()
"Mathurin".strip("Ma")
# Out:
# 'thurin'

# %%
"Sylvain".strip("Ma")
# Out:
# 'Sylvain'

# %%
# difference between "print" and "print()"

# %%
europe.columns = years

# %%
europe
# Out:
#                                 1952          1957          1962  \
# country
# Albania                  1601.056136   1942.284244   2312.888958
# Austria                  6137.076492   8842.598030  10750.721110
# Belgium                  8343.105127   9714.960623  10991.206760
# Bosnia and Herzegovina    973.533195   1353.989176   1709.683679
# Bulgaria                 2444.286648   3008.670727   4254.337839
# Croatia                  3119.236520   4338.231617   5477.890018
# Czech Republic           6876.140250   8256.343918  10136.867130
# Denmark                  9692.385245  11099.659350  13583.313510
# Finland                  6424.519071   7545.415386   9371.842561
# France                   7029.809327   8662.834898  10560.485530
# Germany                  7144.114393  10187.826650  12902.462910
# Greece                   3530.690067   4916.299889   6017.190733
# Hungary                  5263.673816   6040.180011   7550.359877
# ...

# %%
type(europe)
# Out:
# pandas.core.frame.DataFrame

# %%
# to know all the attributes of an object
dir(europe)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 50, 100, 200]

plt.figure(figsize=(3, 3))
plt.scatter(time, position, marker='+', s=100)
plt.plot(time, position)
plt.ylabel("Position (m)")
plt.xlabel("Time (s)", fontsize=16)
# Out:
# Text(0.5, 0, 'Time (s)')

# %%
europe.loc["Serbia"].plot()

# %%
europe.loc[["Serbia", "France"]].T
# Out:
# country        Serbia        France
# 1952      3581.459448   7029.809327
# 1957      4981.090891   8662.834898
# 1962      6289.629157  10560.485530
# 1967      7991.707066  12999.917660
# 1972     10522.067490  16107.191710
# 1977     12980.669560  18292.635140
# 1982     15181.092700  20293.897460
# 1987     15870.878510  22066.442140
# 1992      9325.068238  24703.796150
# 1997      7914.320304  25889.784870
# 2002      7236.075251  28926.032340
# 2007      9786.534714  30470.016700

# %%
europe.loc[["Serbia", "France"]].T.plot()
# Out:
# <AxesSubplot: >

# %%
europe.loc["Switzerland"].plot(color="green", linestyle='--')
# Out:
# <AxesSubplot: >

# %%
# TODO: plot the gdp of Switzerland with a green dashed line 
subset = europe.loc[:"France"]
subset.T.plot()
# Out:
# <AxesSubplot: >

# %%
plt.plot(europe.loc["France"], color="orange")
